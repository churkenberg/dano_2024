# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('data\data.csv')
data.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1284\1532519782.py:1: SyntaxWarning: invalid escape sequence '\d'
#   data = pd.read_csv('data\data.csv')
#    Unnamed: 0      party_rk               region  \
# 0           0  6.220256e+08               Москва
# 1           1  6.961338e+08  Воронежская область
# 2           2  1.057242e+09          Севастополь
# 3           3  3.006247e+08      Республика Тыва
# 4           4  7.024843e+08  Воронежская область
#
#                offenceshortstatement  engine_type  engine_power  \
# 0                Движение по обочине          1.8         152.0
# 1  Превышение скорости на 40-60 км/ч          1.6          73.0
# 2  Превышение скорости на 20-40 км/ч          2.5         145.0
# 3  Превышение скорости на 20-40 км/ч          2.0         150.0
# 4  Превышение скорости на 20-40 км/ч          2.3         155.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97307 entries, 0 to 97306
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 97307 non-null  int64
#  1   party_rk                   97306 non-null  float64
#  2   region                     97306 non-null  object
#  3   offenceshortstatement      97306 non-null  object
#  4   engine_type                97306 non-null  float64
#  5   engine_power               97306 non-null  float64
#  6   body_type                  97306 non-null  object
#  7   auto_mark                  97306 non-null  object
#  8   auto_year                  97306 non-null  float64
#  9   auto_model                 97306 non-null  object
#  10  color                      97306 non-null  object
#  11  gear_type                  97306 non-null  object
#  12  car_price                  97306 non-null  float64
# ...

# %%
data['offencedatetime'] = pd.to_datetime(data['offencedatetime'])

# %%
data.drop(columns='Unnamed: 0', axis=1, inplace=True)

# %%
data.describe()
# Out:
#            party_rk   engine_type  engine_power     auto_year     car_price  \
# count  9.730600e+04  97306.000000  97306.000000  97306.000000  97306.000000
# mean   5.449193e+08      2.156845    161.532329   2013.258463   1581.552391
# min    1.180000e+02      0.000000      0.000000   1910.000000     46.000000
# 25%    2.724549e+08      1.600000    107.000000   2009.000000    659.000000
# 50%    5.453083e+08      1.800000    145.000000   2013.000000   1105.000000
# 75%    7.856307e+08      2.400000    190.000000   2018.000000   1945.000000
# max    1.228628e+09    999.000000   1770.000000   2024.000000  35470.000000
# std    3.076237e+08      8.494550     79.588675      6.135761   1622.693079
#
#        gender_cd_M-1_F-0           age  children_cnt  \
# count       97307.000000  97306.000000  97306.000000
# mean            0.687299     37.610127      0.139714
# min             0.000000      4.000000      0.000000
# 25%             0.000000     30.000000      0.000000
# ...

# %% [markdown]
# SARIMAX

# %%
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.forecasting.base import ForecastingHorizon

# %% [markdown]
# можно под y ебануть возраст водилы и возраст машины, бинарник с выходным или рабочим днем, колвом детей, бинарник с полом и месячной зп
# и сконектить связь с датой

# %%
y = data.age

# %%
from sktime.utils.plotting import plot_series

# %%
y = y.to_numpy(y)

# %%
y_train, y_test = temporal_train_test_split(y, test_size=48)
fn = ForecastingHorizon(y_test.index, is_relativ=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 y_train, y_test = temporal_train_test_split(y, test_size=48)
#       2 fn = ForecastingHorizon(y_test.index, is_relativ=False)
#
# File c:\Users\Administrator\anaconda3\Lib\site-packages\sktime\forecasting\model_selection\__init__.py:45, in temporal_train_test_split(y, X, test_size, train_size, fh, anchor)
#      34 from sktime.split import temporal_train_test_split as _tts
#      36 warn(
#      37     "WARNING - the old location of temporal_train_test_split in "
#      38     "sktime.forecasting.model_selection is deprecated and is scheduled for "
#    (...)
#      42     DeprecationWarning,
#      43 )
# ---> 45 return _tts(
#      46     y=y, X=X, test_size=test_size, train_size=train_size, fh=fh, anchor=anchor
#      47 )
#
# ...

# %%
y_train, y_test = temporal_train_test_split(y, test_size=48)
fn = ForecastingHorizon(y_test.index, is_relativ=False)

plot_series(y_train, y_test, labels=['y_train', 'y_test'])
print(y_train.shape[0], y_test.shape[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 y_train, y_test = temporal_train_test_split(y, test_size=48)
#       2 fn = ForecastingHorizon(y_test.index, is_relativ=False)
#       4 plot_series(y_train, y_test, labels=['y_train', 'y_test'])
#
# File c:\Users\Administrator\anaconda3\Lib\site-packages\sktime\forecasting\model_selection\__init__.py:45, in temporal_train_test_split(y, X, test_size, train_size, fh, anchor)
#      34 from sktime.split import temporal_train_test_split as _tts
#      36 warn(
#      37     "WARNING - the old location of temporal_train_test_split in "
#      38     "sktime.forecasting.model_selection is deprecated and is scheduled for "
#    (...)
#      42     DeprecationWarning,
#      43 )
# ---> 45 return _tts(
#      46     y=y, X=X, test_size=test_size, train_size=train_size, fh=fh, anchor=anchor
#      47 )
#
# ...
